# %%
import pandas as pd
import numpy as np
from IPython.display import display

# %%
df = pd.read_csv("countries.csv")
df = df.drop("Capital", axis=1)
df = df.drop("Url", axis=1)

# print(df.shape)

display (df[df["Continent"] == "Africa"])

display(df)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country (en)</th>
#       <th>Country (de)</th>
#       <th>Country (local)</th>
#       <th>Country code</th>
#       <th>Continent</th>
#       <th>Population</th>
#       <th>Area</th>
#       <th>Coastline</th>
#       <th>Government form</th>
#       <th>Currency</th>
#       <th>Currency code</th>
#       <th>Dialing prefix</th>
#       <th>Birthrate</th>
#       <th>Deathrate</th>
#       <th>Life expectancy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Egypt</td>
#       <td>Ägypten</td>
#       <td>Misr</td>
#       <td>EG</td>
#       <td>Africa</td>
#       <td>94666993</td>
#       <td>1001450</td>
#       <td>2450</td>
#       <td>Presidential republic</td>
#       <td>Pfund</td>
#       <td>EGP</td>
#       <td>20</td>
#       <td>30.3</td>
#       <td>4.7</td>
#       <td>72.7</td>
#     </tr>
#     <tr>
# ...
